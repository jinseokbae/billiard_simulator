# %%
import csv
import numpy as np
from matplotlib import pyplot as plt

# %%
myFile = np.genfromtxt('images/ball_episode_000.txt',delimiter=',')

# %%
image = myFile[213].reshape(256,256,3)
image = image.astype(np.uint8)
plt.imshow(image)
